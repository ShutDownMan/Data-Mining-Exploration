# %%
import pandas as pd

# import the data
data = pd.read_excel('./data/Case_Studies/CaseStudy11_TBI.xlsx');
data.head()
# Out:
#    id  age     sex     mechanism field.gcs er.gcs icu.gcs worst.gcs 6m.gose  \
# 0   1   19    Male          Fall        10     10      10        10       5
# 1   2   55    Male         Blunt         .      3       3         3       5
# 2   3   24    Male          Fall        12     12       8         8       7
# 3   4   57  Female          Fall         4      4       6         4       3
# 4   5   54  Female  Peds_vs_Auto        14     11       8         8       5
#
#    2013.gose  skull.fx  temp.injury  surgery spikes.hr min.hr max.hr  \
# 0          5         0            1        1         .      .      .
# 1          7         1            1        1    168.74     14    757
# 2          7         1            0        0     37.37      0    351
# 3          3         1            1        1      4.35      0     59
# 4          7         0            1        1     54.59      0    284
#
#    acute.sz  late.sz  ever.sz
# 0         1        1        1
# 1         0        1        1
# ...
